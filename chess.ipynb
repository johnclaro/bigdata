# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams["figure.figsize"] = (20,10)

df = pd.read_csv('files/plies.csv')

plt.xlabel('Number Of Half Moves (Plies)')
plt.ylabel('Number Of Games')
plt.scatter('Plies', 'BlackWins', data=df, alpha=0.4, color='red', label='Black Wins')
plt.scatter('Plies', 'WhiteWins', data=df, alpha=0.4, color='blue', label='White Wins')
plt.scatter('Plies', 'Draw', data=df, alpha=0.2, color='green', label="Draw")
plt.legend()
plt.show()
