# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 

# df=pd.DataFrame({
#     'Plies': range(1,11), 
#     '0-1': np.random.randn(10), 
#     '1-0': np.random.randn(10) + range(1,11), 
#     '1/2-1/2': np.random.randn(10) + range(11,21)
# })
# print(df)
df = pd.read_csv('files/plies.csv')
print(df)

# multiple line plots
plt.plot('Plies', 'BlackWins', data=df, marker='', color='skyblue', linewidth=1, label='Black Wins')
plt.plot('Plies', 'WhiteWins', data=df, marker='', color='orange', linewidth=1, label='White Wins')
plt.plot('Plies', 'Draw', data=df, marker='', color='green', linewidth=1, label="Draw")
# show legend
plt.legend()

plt.rcParams["figure.figsize"] = (20,20)
# show graph
plt.show()
# Out:
#      Plies  BlackWins  WhiteWins  Draw
# 0        2        366        152     9
# 1        3         39        339     7
# 2        4        132         22     0
# 3        5         11        149     5
# 4        6         89         20     1
# ..     ...        ...        ...   ...
# 249    266          0          0     1
# 250    273          0          0     1
# 251    297          0          0     2
# 252    303          0          0     1
# 253    304          0          0     1
#
# [254 rows x 4 columns]
